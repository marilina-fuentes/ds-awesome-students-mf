# %%
import matplotlib.pyplot as plt

# Crea el gráfico del mapa conceptual
plt.figure(figsize=(8, 6))
plt.title("Conceptos clave de aprendizaje de máquina")
plt.axis('off')

# Define los nodos y conexiones
nodes = ["Aprendizaje de máquina", "Modelos no supervisados", "Data compression",
         "Anomalías", "Segmentación", "Compresión con pérdida", "Compresión sin pérdida"]
edges = [("Aprendizaje de máquina", "Modelos no supervisados"),
         ("Aprendizaje de máquina", "Data compression"),
         ("Data compression", "Compresión con pérdida"),
         ("Data compression", "Compresión sin pérdida"),
         ("Aprendizaje de máquina", "Anomalías"),
         ("Aprendizaje de máquina", "Segmentación")]

# Dibuja los nodos y conexiones
pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=2000, node_color='lightblue', alpha=0.9)
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')
nx.draw_networkx_edges(G, pos, edge_color='gray', width=1, alpha=0.5)

# Muestra el gráfico
plt.show()
